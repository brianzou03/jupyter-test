# %% [markdown]
# # Penguin Classification

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Import necessary libraries - Pandas (handling data), Seaborn (data visualization)

# %%
df = pd.read_csv('data/penguin-data.csv').dropna()  # this missing data will cause confusion

# selecting columns rather than passing usecols allows us to reorder them
df[['flipper_length_mm', 'bill_length_mm', 'species']]
# Out:
#      flipper_length_mm  bill_length_mm    species
# 0                181.0            39.1     Adelie
# 1                186.0            39.5     Adelie
# 2                195.0            40.3     Adelie
# 4                193.0            36.7     Adelie
# 5                190.0            39.3     Adelie
# ..                 ...             ...        ...
# 339              207.0            55.8  Chinstrap
# 340              202.0            43.5  Chinstrap
# 341              193.0            49.6  Chinstrap
# 342              210.0            50.8  Chinstrap
# 343              198.0            50.2  Chinstrap
#
# [333 rows x 3 columns]

# %% [markdown]
# ##### Displaying penguin data on a graph with seaborn

# %%
sns.relplot(
    data = df,
    x = 'bill_length_mm',
    y = 'flipper_length_mm',
    hue = 'species',
    height=8,
    hue_order = ['Adelie', 'Gentoo', 'Chinstrap']
)
